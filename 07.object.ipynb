# %%
class A:
    print("Hello", end="")
    
print("World")
# Out:
# HelloWorld

# %%
import file_to_import
# Out:
# Hello Outside

# %%
class A:
    x = []

a1, a2 = A(), A()
a1.x.append(1)
a2.x.append(2)

print(a1.x)
# Out:
# [1, 2]

# %%
class A:
    x = 1

class B(A):
    pass

b = B()
b.x = 2
print(A.x, B.x, b.x)
# Out:
# 1 1 2

# %%
class A:
    x = 1

class B(A):
    pass

b = B()


print("B.x", B.x)
b.x = 2
print("b.x", b.x)
print("B.x", B.x)
# Out:
# B.x 1
# b.x 2
# B.x 1

# %%
new_c = B()
print(new_c.x)
# Out:
# 1

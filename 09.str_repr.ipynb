# %%
class A:
    def __str__(self):
        return "Cool"
    
print(A())
# Out:
# Cool

# %%
class A:
    pass
    # def __str__(self):
    #     return "Cool Str"
    
    # def __repr__(self):
    #     return "Cool Repr"
    
print(A())

# %%
class A:
    # def __str__(self):
    #     return "Cool Str"
    
    def __repr__(self):
        return "Cool Repr"
    
print(A())
# Out:
# Cool Repr

# %%
class A:
    def __str__(self):
        return "Cool Str"
    
    def __repr__(self):
        return "Cool Repr"
    
print(A())
# Out:
# Cool Str

# %%
class A:
    def __str__(self):
        return "Cool Str"
    
    def __repr__(self):
        return "Cool Repr"
    
A()
# Out:
# Cool Repr

# %%
class A:
    def __str__(self):
        return "Cool Str"
    
    def __repr__(self):
        return "Cool Repr"
    
x = str(A())
x
# Out:
# 'Cool Str'

# %%
class A:
    def __len__(self):
        return -1
    
a = A()
print(len(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3         return -1
#       5 a = A()
# ----> 6 print(len(a))
#
# ValueError: __len__() should return >= 0

# %%
def f(x=print("hello")):
    pass

print("done")
# Out:
# hello
# done

# %%
x = "ABC"
d = [x for x in "ABC"]
print(x)
# Out:
# ABC

# %%
def f():pass

print(type(f))
print(type(type(f)))
# Out:
# <class 'function'>
# <class 'type'>

# %%
type("MyClass", (), {"a":2})
# Out:
# __main__.MyClass

# %%
a, *b, c = [1, 2, 3]
print(a, b, c)
# Out:
# 1 [2] 3

# %%
a, *b, c = [1, 2, 3, 4, 5]
print(a, b, c)
# Out:
# 1 [2, 3, 4] 5

# %%
def my_func(a, c, *b ):
    pass

# %%
my_func(1, 2, 3, 4, 5)

# %%
any([100, 0, 2])
# Out:
# True

# %%
all([100, 0, 2])
# Out:
# False

# %%
hash("hello")
# Out:
# -8255183682758722418

# %%
hash("hello")
# Out:
# -8255183682758722418

# %%
hash("hellO")
# Out:
# 7066123704701363449

# %%
-8255183682758722418
-8255183682758722419

# %%
-8255183682758722418
-1255183682758722418

# %%
map
# Out:
# map

# %%
filter
# Out:
# filter

# %%
from functools import reduce

# %%
reduce
# Out:
# <function _functools.reduce>

# %%
x = 10
f =  lambda x : x + 5
x = 20
print(f(x))
# Out:
# 25

# %%
o = {
    "+":lambda a, b : a + b,
    "*":lambda a, b : a * b
}
print(o['+'](o['*'](3, 4), 2))
# Out:
# 14

# %%
o['*'](3, 4)
# Out:
# 12

# %%
o['+'](12, 2)
# Out:
# 14

# %%
def outer():
    x = []
    def inner(val):
        x.append(val)
        return x
    
    return inner

f = outer()
print(f(1), f(2))
# Out:
# [1, 2] [1, 2]

# %%
print(f(1)) 
print(f(2))
# Out:
# [1, 2, 1]
# [1, 2, 1, 2]

# %%
def make():
    funcs = []
    for i in range(3):
        funcs.append(lambda:i)
    return funcs

print([f() for f in make()])
# Out:
# [2, 2, 2]

# %%
nums = [10, 2, 33, 4, 0]
a = sorted(nums, key=bool)
print(a)
# Out:
# [0, 10, 2, 33, 4]

# %%
nums = [10, 2, 0.0, 33, 4, 0, True, False]
a = sorted(nums, key=bool)
print(a)
# Out:
# [0.0, 0, False, 10, 2, 33, 4, True]

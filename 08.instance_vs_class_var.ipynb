# %%
class MyClass:
    pass

# %%
my_object = MyClass()
my_object

# %%
my_object.x = 10

# %%
my_object.x
# Out:
# 10

# %%
another_object = MyClass()
another_object.x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 another_object = MyClass()
# ----> 2 another_object.x
#
# AttributeError: 'MyClass' object has no attribute 'x'

# %%
class SecondClass:
    class_variabile = 1234

# %%
obj_second_class = SecondClass()
another_obj_second_class = SecondClass()

# %%
obj_second_class.class_variabile
# Out:
# 1234

# %%
another_obj_second_class.class_variabile
# Out:
# 1234

# %%
obj_second_class.class_variabile = 9999

# %%
obj_second_class.class_variabile
# Out:
# 9999

# %%
another_obj_second_class.class_variabile
# Out:
# 1234

# %%
id(another_obj_second_class.class_variabile)
# Out:
# 4581216688

# %%
id(obj_second_class.class_variabile)
# Out:
# 4581569040

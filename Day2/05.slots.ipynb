# %%
class A:
    __slots__ = ('x')

a = A()
a.x = 10
# a.y = 20

# %%
class A:
    __slots__ = ('x', 'y')

a = A()
a.x = 10
a.y = 20

# %%
A.__slots__
# Out:
# ('x', 'y')

# %%
A.__slots__ = ('x', 'y', 'z')

# %%
A.__slots__
# Out:
# ('x', 'y', 'z')

# %%
a = A()
a.x = 10
a.y = 20

# %%
a.z = 100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a.z = 100
#
# AttributeError: 'A' object attribute 'z' is read-only

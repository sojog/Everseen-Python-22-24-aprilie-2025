# %%
PI = 3.141592353

# %%
PI = 2

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pi = 10
math.pi
# Out:
# 10

# %%
from typing import Any, final

# %%
MY_CONST:final = 1235

# %%
MY_CONST = 23
MY_CONST
# Out:
# 23

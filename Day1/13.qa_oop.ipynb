# %%
class Test:
    val = 10
    def __init__(self):
        self.val = 20

t = Test()
print(t.val, end=" ")
del t.val
print(t.val)
# Out:
# 20 10

# %%
del t.val
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del t.val
#
# AttributeError: 'Test' object has no attribute 'val'

# %%
Test.val
# Out:
# 10

# %%
del Test.val

# %%
Test.val
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Test.val
#
# AttributeError: type object 'Test' has no attribute 'val'

# %%
class A:
    def __init__(self):
        self.__x = 10

a = A()
print(a.__x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       3         self.__x = 10
#       5 a = A()
# ----> 6 print(a.__x)
#
# AttributeError: 'A' object has no attribute '__x'

# %%
class A:
    def __len__(self):
        print("len_called", end=" ")
        return 0

a = A()
print(bool(a))
# Out:
# len_called False

# %%
class A:
    pass
    # def __len__(self):
    #     print("len_called", end=" ")
    #     return 0

a = A()
print(bool(a))
# Out:
# True

# %%
bool(3141)
# Out:
# True

# %%
bool([32, 32])
# Out:
# True

# %%
bool("0")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool({0})
# Out:
# True

# %%
class A:
    def __iter__(self):
        return self
    
    def __next__(self):
        return 1
    
for i in A():
    print(i)
    break
# Out:
# 1

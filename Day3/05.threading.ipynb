# %%
import time


def sum_of_squares(n):
    return sum(i*i for i in range(n))

if __name__ == "__main__":
    numbers = [10_000_000, 20_000_000, 30_000_000, 40_000_000]
    start = time.time()

    results = [sum_of_squares(n) for n in numbers]
    
    stop = time.time()

    print("Results", results)
    print(f"Single Threaded time  {stop-start:.2f} seconds")
# Out:
# Results [333333283333335000000, 2666666466666670000000, 8999999550000005000000, 21333332533333340000000]
# Single Threaded time  4.27 seconds

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(3):{
    print(i)
}
# Out:
# 0
# 1
# 2

# %%
c
# Out:
#   Cell In[5], line 2
#     print(i);print(i)
#             ^
# SyntaxError: invalid syntax

# %%
for i in range(3):
    print(i);print(i)
# Out:
# 0
# 0
# 1
# 1
# 2
# 2

# %%
x = 10
while (x > 0) : {
    print(x),
    x := 0
}
# Out:
# 10

# %%
for i in range(3):{
    print(i),
    print(i)
}
# Out:
# 0
# 0
# 1
# 1
# 2
# 2
